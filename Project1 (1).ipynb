# %%
# !pip install numpy pandas matplotlib seaborn

# %%
import pandas as pd

# %%
df = pd.read_csv("Downloads/archive/games.csv")

# %%
df.columns
# Out:
# Index(['app_id', 'title', 'date_release', 'win', 'mac', 'linux', 'rating',
#        'positive_ratio', 'user_reviews', 'price_final', 'price_original',
#        'discount', 'steam_deck'],
#       dtype='object')

# %%
df.head()
# Out:
#    app_id                              title date_release   win    mac  linux  \
# 0   13500  Prince of Persia: Warrior Within™   2008-11-21  True  False  False
# 1   22364            BRINK: Agents of Change   2011-08-03  True  False  False
# 2  113020       Monaco: What's Yours Is Mine   2013-04-24  True   True   True
# 3  226560                 Escape Dead Island   2014-11-18  True  False  False
# 4  249050            Dungeon of the ENDLESS™   2014-10-27  True   True  False
#
#           rating  positive_ratio  user_reviews  price_final  price_original  \
# 0  Very Positive              84          2199         9.99            9.99
# 1       Positive              85            21         2.99            2.99
# 2  Very Positive              92          3722        14.99           14.99
# 3          Mixed              61           873        14.99           14.99
# 4  Very Positive              88          8784        11.99           11.99
#
#    discount  steam_deck
# ...

# %%
df.dtypes
# Out:
# app_id              int64
# title              object
# date_release       object
# win                  bool
# mac                  bool
# linux                bool
# rating             object
# positive_ratio      int64
# user_reviews        int64
# price_final       float64
# price_original    float64
# discount          float64
# steam_deck           bool
# dtype: object

# %%
df.shape
# Out:
# (50872, 13)

# %%
df["title"]
# Out:
# 0                Prince of Persia: Warrior Within™
# 1                          BRINK: Agents of Change
# 2                     Monaco: What's Yours Is Mine
# 3                               Escape Dead Island
# 4                          Dungeon of the ENDLESS™
#                            ...
# 50867    I Expect You To Die 3: Cog in the Machine
# 50868                                     PAYDAY 3
# 50869                                   Eternights
# 50870                          Forgive Me Father 2
# 50871                                    FatalZone
# Name: title, Length: 50872, dtype: object

# %%
df[df['mac'] == True]
# Out:
#         app_id                                              title  \
# 2       113020                       Monaco: What's Yours Is Mine
# 4       249050                            Dungeon of the ENDLESS™
# 6       253980                                            Enclave
# 13       29180                                              Osmos
# 18      245950  Borderlands 2: Headhunter 4: Wedding Day Massacre
# ...        ...                                                ...
# 50830  2195430                   Two Point Campus: Medical School
# 50835  2446110                          Stacklands: Cursed Worlds
# 50848  2515460               Northgard - Kernev Clan of the Stoat
# 50851  1555150                                     Pocket Bravery
# 50862  1407180                                       Lawgivers II
#
#       date_release   win   mac  linux           rating  positive_ratio  \
# 2       2013-04-24  True  True   True    Very Positive              92
# ...

# %%
df.isna().sum()
# Out:
# app_id            0
# title             0
# date_release      0
# win               0
# mac               0
# linux             0
# rating            0
# positive_ratio    0
# user_reviews      0
# price_final       0
# price_original    0
# discount          0
# steam_deck        0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(rc={"figure.figsize":(20, 14)})
sns.barplot(data=df, x = 'mac', y = 'positive_ratio', hue = 'mac')

plt.savefig("macbargraph3.png")

# %%
sns.set(rc={"figure.figsize":(40,34)})
sns.barplot(data=df, x = 'discount', y = 'positive_ratio')
# Out:
# <Axes: xlabel='discount', ylabel='positive_ratio'>

# %%
sns.set(rc={"figure.figsize":(30,24)})
sns.barplot(data=df, x = 'steam_deck', y = 'positive_ratio', hue = 'steam_deck')
# Out:
# <Axes: xlabel='steam_deck', ylabel='positive_ratio'>

# %%
sns.set(rc={"figure.figsize":(20, 14)})
sns.barplot(data=df, x = 'linux', y = 'positive_ratio', hue = 'linux')

plt.savefig("linuxbargraph3.png")

# %%
sns.set(rc={"figure.figsize":(18, 10)})
sns.barplot(data=df, x = 'rating', y = 'discount', hue = 'rating')

plt.savefig("ratingbargraph2.png")

# %%
df.mode()
# Out:
#         app_id title date_release   win    mac  linux    rating  \
# 0           10  Loop   2020-06-18  True  False  False  Positive
# 1           20   NaN          NaN   NaN    NaN    NaN       NaN
# 2           30   NaN          NaN   NaN    NaN    NaN       NaN
# 3           40   NaN          NaN   NaN    NaN    NaN       NaN
# 4           50   NaN          NaN   NaN    NaN    NaN       NaN
# ...        ...   ...          ...   ...    ...    ...       ...
# 50867  2581740   NaN          NaN   NaN    NaN    NaN       NaN
# 50868  2585630   NaN          NaN   NaN    NaN    NaN       NaN
# 50869  2585640   NaN          NaN   NaN    NaN    NaN       NaN
# 50870  2593020   NaN          NaN   NaN    NaN    NaN       NaN
# 50871  2599300   NaN          NaN   NaN    NaN    NaN       NaN
#
#        positive_ratio  user_reviews  price_final  price_original  discount  \
# 0               100.0          10.0          0.0             0.0       0.0
# ...

# %%
df.mean
# Out:
# <bound method DataFrame.mean of         app_id                                      title date_release   win  \
# 0        13500          Prince of Persia: Warrior Within™   2008-11-21  True
# 1        22364                    BRINK: Agents of Change   2011-08-03  True
# 2       113020               Monaco: What's Yours Is Mine   2013-04-24  True
# 3       226560                         Escape Dead Island   2014-11-18  True
# 4       249050                    Dungeon of the ENDLESS™   2014-10-27  True
# ...        ...                                        ...          ...   ...
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True
# 50868  1272080                                   PAYDAY 3   2023-09-21  True
# 50869  1402110                                 Eternights   2023-09-11  True
# 50870  2272250                        Forgive Me Father 2   2023-10-19  True
# 50871  2488510                                  FatalZone   2023-10-23  True
#
# ...

# %%
df
# Out:
#         app_id                                      title date_release   win  \
# 0        13500          Prince of Persia: Warrior Within™   2008-11-21  True
# 1        22364                    BRINK: Agents of Change   2011-08-03  True
# 2       113020               Monaco: What's Yours Is Mine   2013-04-24  True
# 3       226560                         Escape Dead Island   2014-11-18  True
# 4       249050                    Dungeon of the ENDLESS™   2014-10-27  True
# ...        ...                                        ...          ...   ...
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True
# 50868  1272080                                   PAYDAY 3   2023-09-21  True
# 50869  1402110                                 Eternights   2023-09-11  True
# 50870  2272250                        Forgive Me Father 2   2023-10-19  True
# 50871  2488510                                  FatalZone   2023-10-23  True
#
# ...

# %%
sns.set(rc={"figure.figsize":(18, 10)})
sns.barplot(data=df, x = 'rating', y = 'user_reviews', hue = 'rating')

plt.savefig("userreviewsbargraph1.png")

# %%
sns.set(rc={"figure.figsize":(25,18)})
sns.barplot(data=df, x = 'rating', y = 'positive_ratio', hue = 'rating')
# Out:
# <Axes: xlabel='rating', ylabel='positive_ratio'>

# %%
df.mean
# Out:
# <bound method DataFrame.mean of         app_id                                      title date_release   win  \
# 0        13500          Prince of Persia: Warrior Within™   2008-11-21  True
# 1        22364                    BRINK: Agents of Change   2011-08-03  True
# 2       113020               Monaco: What's Yours Is Mine   2013-04-24  True
# 3       226560                         Escape Dead Island   2014-11-18  True
# 4       249050                    Dungeon of the ENDLESS™   2014-10-27  True
# ...        ...                                        ...          ...   ...
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True
# 50868  1272080                                   PAYDAY 3   2023-09-21  True
# 50869  1402110                                 Eternights   2023-09-11  True
# 50870  2272250                        Forgive Me Father 2   2023-10-19  True
# 50871  2488510                                  FatalZone   2023-10-23  True
#
# ...
